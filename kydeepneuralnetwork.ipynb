# %% [markdown]
# <a href="https://colab.research.google.com/github/yahyakesenek/KOU/blob/master/kydeepneuralnetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Yahya Kesenek 196112006
# Derin Öğrenme - Prof. Dr. Yaşar Becerikli
#
# Fashion Mnist CNN kullanarak sınıflandırma Projesi

# %%
import numpy as np
from numpy import asarray
import cv2
import matplotlib.pyplot as pl

import tensorflow as tf
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
TEST=True
img=x_train[0]
#img = cv2.imread(x_train[0],cv2.IMREAD_GRAYSCALE)/255
pl.imshow(img,cmap="gray")
if TEST:
  pl.show()
img.shape
# Out:
# (28, 28)

# %%
class Layer:
  """Layer abstract class"""

  def __init__(self):
    pass

  def backward(self):
    pass


class Flatten(Layer):
  def forward(self,output):
    self.input=output.shape
    flat=output.reshape((36,8))
    self.modified = flat
    return self.modified
  def backward(self,output):
    return output.reshape(self.input)

# %%
class Linear(Layer):
  def __init__(self, input_dim, output_dim):
    self.weights = np.random.rand(output_dim, input_dim)
    self.biases = np.random.rand(output_dim, 1)
    self.type = 'Linear'

  def __str__(self):
    return f"{self.type} Layer"

  def forward(self, input_val):
    self._prev_acti = input_val
    return np.matmul(self.weights, input_val) + self.biases

  def backward(self, dA,learning_rate):
    dW = np.dot(dA, self._prev_acti.T)
    dB = dA.mean(axis=1, keepdims=True)

    delta = np.dot(self.weights.T, dA)
    self.weights = self.weights - learning_rate * dW
    self.biases = self.biases - learning_rate * dB
    return delta

# %%
class Sigmoid(Layer):
  def __init__(self, output_dim):
    self.units = output_dim
    self.type = 'Sigmoid'

  def __str__(self):
    return f"{self.type} Layer"

  def forward(self, input_val):
    self._prev_acti = 1 / (1 + np.exp(-input_val))
    return self._prev_acti

  def backward(self, dJ):
    sig = self._prev_acti
    return dJ * sig * (1 - sig)

# %%
class Conv:
  def __init__(self,num_filters,filter_size):
    self.num_filters=num_filters
    self.filter_size=filter_size
    self.conv_filter=np.random.randn(num_filters,filter_size,filter_size)/(filter_size*filter_size)#(x,4,4)=> 16 ya bölünerek nırmalize edilir.

  def image_region(self,image):#parça üretim amacıyla kullanılmaktadır. n-x+1 patch boyutu
    height,width=image.shape
    self.image = image
    for j in range(height-self.filter_size+1):
      for k in range(width-self.filter_size+1):
        image_patch=image[j:(j+self.filter_size),k:(k+self.filter_size)]
        yield image_patch,j,k
  def forward_prop(self,image):
    height,width=image.shape
    conv_out=np.zeros((height-self.filter_size+1,width-self.filter_size+1,self.num_filters))
    for image_patch,i,j in self.image_region(image):
      conv_out[i,j] = np.sum(image_patch*self.conv_filter,axis=(1,2))
    return conv_out
  def back_prop(self,dl_dout,learning_rate):#dl_dout -> max-pool değeriyle gelecek
    dl=np.zeros(self.conv_filter.shape)
    for image_patch,i,j in self.image_region(self.image):
      for k in range(self.num_filters):
        dl[k] +=image_patch*dl_dout[i,j,k]
    self.conv_filter -=learning_rate*dl
    return dl

# %%
conv = Conv(18,7)
out = conv.forward_prop(img)
print(img.shape)
print(out.shape)
pl.imshow(out[:,:,8],cmap="gray") # 3 değeri 0-17 a kadar değer alabilir
if TEST:
  pl.show()
# Out:
# (28, 28)
# (22, 22, 18)

# %%
class MaxPool:
  def __init__(self, filter_size):
    self.filter_size = filter_size

  def image_region(self, image):  # parça üretim amacıyla kullanılmaktadır. n-x+1 patch boyutu
    height, width = image.shape[0] // self.filter_size, image.shape[1] // self.filter_size
    self.image = image
    for i in range(height - self.filter_size + 1):
      for j in range(width - self.filter_size + 1):
        image_patch = image[(i * self.filter_size):(i * self.filter_size + self.filter_size),
                      (j * self.filter_size):(j * self.filter_size + self.filter_size)]
        yield image_patch, i, j

  def forward_prop(self, image):
    height, width, num_filters = image.shape
    self.num_filters = num_filters
    conv_out = np.zeros((height // self.filter_size, width // self.filter_size, num_filters))
    for image_patch, i, j in self.image_region(image):
      conv_out[i, j] = np.amax(image_patch * self.filter_size, axis=(0, 1))
    return conv_out

  def back_prop(self, dl_dout):  # softmax kullanımına dikkat edilecek  dl_out bir softmax
    dl = np.zeros(self.image.shape)
    for image_patch, i, j in self.image_region(self.image):
      for k in range(self.num_filters):
        h, w, filter = image_patch.shape
        max_val = np.amax(image_patch, axis=(0, 1))
        for i1 in range(h):
          for j1 in range(w):
            for k1 in range(filter):
              if image_patch[i1, j1, k1] == max_val[k1]:
                dl[i * self.filter_size + i1, j * self.filter_size + j1, k1] = dl_dout[j, j, k1]

    return dl

# %%
maxpol = MaxPool(4)
out = maxpol.forward_prop(out)
print(out.shape)
pl.imshow(out[:,:,7],cmap="gray")
if TEST:
  pl.show()
# Out:
# (5, 5, 18)

# %%
class Softmax:
  def __init__(self,_input,soft):
    self.weight=np.random.randn(_input,soft)/_input
    self.bias = np.zeros(soft)
  def forward(self,image):
    self.orig_im_shape = image.shape
    flattened = image.flatten()
    self.modified = flattened
    self.out=np.dot(self.modified,self.weight)+self.bias
    exp_out = np.exp(self.out)
    return exp_out/np.sum(exp_out,axis=0)
  def backwad(self,dl_dout,learning_rate):
    for i,grad in enumerate(dl_dout):
      if grad == 0:
        continue
      transformation = np.exp(self.out)
      s_total = np.sum(transformation)
      dy_dz = -transformation[i]*transformation/(s_total**2)#z ye göre türev
      dy_dz[i] = transformation[i]*(s_total-transformation[i])/(s_total**2)

      dz_dw = self.modified
      dz_db = 1
      dz_input = self.weight

      dL_dz=grad*dy_dz
      dL_dw = dz_dw[np.newaxis].T @ dL_dz[np.newaxis]
      dL_db = dL_dz*dz_db
      dL_input = dz_input@dL_dz

      self.weight -= learning_rate*dL_dw
      self.bias -=learning_rate*dL_db
      return dL_input.reshape(self.orig_im_shape)

# %%
s=Softmax(5*5*18,10)
out = s.forward(out)
print(out)
# Out:
# [0.07556349 0.03448759 0.06754402 0.231445   0.08310162 0.11427235
#  0.09073511 0.12670659 0.03982007 0.13632416]

# %%
mConv = Conv(8,3) # (28,28,1)=>(26,26,8)
mPool = MaxPool(4) # (26,26,8) => (6,6,8)
mFlatten=Flatten() # 6*6 => (36,8)
mLinear=Linear(input_dim=36,output_dim=8)
mSigmoid=Sigmoid(output_dim=8)
mSoftmax = Softmax(8*8,10) # (8*8) => 64

# %%
def forward(img,label):
  out=mConv.forward_prop(img/255)
  out=mPool.forward_prop(out)
  out=mFlatten.forward(out)
  out=mLinear.forward(out)
  out=mSigmoid.forward(out)
  out=mSoftmax.forward(out)
  cross_ent = -np.log(out[label])
  accuracy = 1 if np.argmax(out) == label else 0
  return out,cross_ent,accuracy

# %%
def train(img,label,learning_rate=0.005):
  out,loss,acc = forward(img,label)
  grad = np.zeros(10)
  grad[label] = -1/out[label]
  grad_back = mSoftmax.backwad(grad,learning_rate)
  grad_back=mSigmoid.backward(grad_back)
  grad_back=mLinear.backward(grad_back,learning_rate)
  grad_back=mFlatten.backward(grad_back)
  grad_back = mPool.back_prop(grad_back)
  grad_back = mConv.back_prop(grad_back,learning_rate)
  return loss,acc

# %%
for epoc in range(10):
  print("Epoch => {}".format(epoc+1))
  loss = 0
  num_correct = 0
  for i,(im,label) in enumerate(zip(x_train,y_train)):
    if i % 100 == 0 and i>0:
      print("{} steps out of 100 steps : average {}  and accuracy {}%".format(i+1,loss/100,num_correct))
      loss=0
      num_correct=0
    l1,acc=train(im,label)
    loss+=l1
    num_correct+=acc
# Out:
# Streaming output truncated to the last 5000 lines.
# 40101 steps out of 100 steps : average 0.7415691100406022  and accuracy 69%
# 40201 steps out of 100 steps : average 0.9007541310208255  and accuracy 65%
# 40301 steps out of 100 steps : average 0.7626301492255877  and accuracy 71%
# 40401 steps out of 100 steps : average 0.7525408525452186  and accuracy 69%
# 40501 steps out of 100 steps : average 0.6939494585038488  and accuracy 73%
# 40601 steps out of 100 steps : average 0.9015765974427827  and accuracy 69%
# 40701 steps out of 100 steps : average 0.6835089803444993  and accuracy 76%
# 40801 steps out of 100 steps : average 0.7801008434084588  and accuracy 67%
# 40901 steps out of 100 steps : average 0.8223833329850975  and accuracy 72%
# 41001 steps out of 100 steps : average 0.7287607480536642  and accuracy 72%
# 41101 steps out of 100 steps : average 0.879222574080506  and accuracy 70%
# 41201 steps out of 100 steps : average 0.7322770555221996  and accuracy 74%
# 41301 steps out of 100 steps : average 0.8065873775886274  and accuracy 68%
# 41401 steps out of 100 steps : average 0.7571456566136961  and accuracy 72%
# 41501 steps out of 100 steps : average 0.8103570451842185  and accuracy 69%
# 41601 steps out of 100 steps : average 0.7331305290225836  and accuracy 71%
# 41701 steps out of 100 steps : average 0.8612500183933294  and accuracy 68%
# 41801 steps out of 100 steps : average 0.7543681037720574  and accuracy 66%
# 41901 steps out of 100 steps : average 0.711246782943631  and accuracy 76%
# 42001 steps out of 100 steps : average 0.8290972792345022  and accuracy 74%
# 42101 steps out of 100 steps : average 0.7909187631731891  and accuracy 70%
# 42201 steps out of 100 steps : average 0.841055582536148  and accuracy 68%
# 42301 steps out of 100 steps : average 0.720457652094356  and accuracy 74%
# 42401 steps out of 100 steps : average 0.7180068624710516  and accuracy 74%
# 42501 steps out of 100 steps : average 0.713699189290861  and accuracy 73%
# 42601 steps out of 100 steps : average 0.7778894114144046  and accuracy 75%
# 42701 steps out of 100 steps : average 0.7396859188709105  and accuracy 72%
# 42801 steps out of 100 steps : average 0.6820178860505816  and accuracy 78%
# 42901 steps out of 100 steps : average 0.8375590287969245  and accuracy 69%
# 43001 steps out of 100 steps : average 0.7443594680527564  and accuracy 74%
# 43101 steps out of 100 steps : average 0.80931459469541  and accuracy 65%
# 43201 steps out of 100 steps : average 0.9095136603270639  and accuracy 66%
# 43301 steps out of 100 steps : average 0.8199872387663283  and accuracy 71%
# 43401 steps out of 100 steps : average 0.9553770294432485  and accuracy 66%
# 43501 steps out of 100 steps : average 0.7671094187634351  and accuracy 71%
# 43601 steps out of 100 steps : average 0.8264801565510418  and accuracy 73%
# 43701 steps out of 100 steps : average 0.644077999815694  and accuracy 76%
# 43801 steps out of 100 steps : average 0.7670144631582523  and accuracy 72%
# 43901 steps out of 100 steps : average 0.898905592001107  and accuracy 61%
# 44001 steps out of 100 steps : average 0.8332125044834839  and accuracy 72%
# 44101 steps out of 100 steps : average 0.7104137984567128  and accuracy 71%
# 44201 steps out of 100 steps : average 0.8375433777189845  and accuracy 67%
# 44301 steps out of 100 steps : average 0.9068170662842431  and accuracy 66%
# 44401 steps out of 100 steps : average 0.7881961105499551  and accuracy 71%
# 44501 steps out of 100 steps : average 0.7774204728105452  and accuracy 69%
# 44601 steps out of 100 steps : average 0.7271597277670704  and accuracy 72%
# 44701 steps out of 100 steps : average 0.7104111298514588  and accuracy 65%
# 44801 steps out of 100 steps : average 0.8685731337558253  and accuracy 68%
# 44901 steps out of 100 steps : average 0.8075312900426121  and accuracy 74%
# 45001 steps out of 100 steps : average 0.9368256475582993  and accuracy 66%
# 45101 steps out of 100 steps : average 0.8514138734155041  and accuracy 70%
# 45201 steps out of 100 steps : average 0.6618032859066418  and accuracy 72%
# 45301 steps out of 100 steps : average 0.9423023485771228  and accuracy 62%
# 45401 steps out of 100 steps : average 0.813477338687528  and accuracy 74%
# 45501 steps out of 100 steps : average 0.7214505051069899  and accuracy 72%
# 45601 steps out of 100 steps : average 0.7698189402859517  and accuracy 70%
# 45701 steps out of 100 steps : average 0.8235917777978178  and accuracy 70%
# 45801 steps out of 100 steps : average 0.7814820607226816  and accuracy 72%
# 45901 steps out of 100 steps : average 0.9277110322926089  and accuracy 72%
# 46001 steps out of 100 steps : average 0.7004086081535403  and accuracy 74%
# 46101 steps out of 100 steps : average 0.8011467043570992  and accuracy 69%
# 46201 steps out of 100 steps : average 0.793299169254374  and accuracy 67%
# 46301 steps out of 100 steps : average 0.9047327908650138  and accuracy 62%
# 46401 steps out of 100 steps : average 0.8082628541077266  and accuracy 69%
# 46501 steps out of 100 steps : average 0.745058595709931  and accuracy 69%
# 46601 steps out of 100 steps : average 0.5969285966224791  and accuracy 75%
# 46701 steps out of 100 steps : average 0.837498703595921  and accuracy 69%
# 46801 steps out of 100 steps : average 0.8048957747734359  and accuracy 69%
# 46901 steps out of 100 steps : average 0.8017562965766304  and accuracy 69%
# 47001 steps out of 100 steps : average 0.8678609040322678  and accuracy 67%
# 47101 steps out of 100 steps : average 0.8971874569041828  and accuracy 71%
# 47201 steps out of 100 steps : average 0.8509801142164326  and accuracy 65%
# 47301 steps out of 100 steps : average 0.8491780825259247  and accuracy 67%
# 47401 steps out of 100 steps : average 0.8651187279665561  and accuracy 67%
# 47501 steps out of 100 steps : average 0.7097881177919966  and accuracy 73%
# 47601 steps out of 100 steps : average 0.8959084157754169  and accuracy 66%
# 47701 steps out of 100 steps : average 0.7582525100039789  and accuracy 69%
# 47801 steps out of 100 steps : average 0.6589708535724594  and accuracy 76%
# 47901 steps out of 100 steps : average 0.7423245363938462  and accuracy 71%
# 48001 steps out of 100 steps : average 0.6826171121931618  and accuracy 78%
# 48101 steps out of 100 steps : average 0.7160995709809785  and accuracy 74%
# 48201 steps out of 100 steps : average 0.7153423758200654  and accuracy 74%
# 48301 steps out of 100 steps : average 0.7483312104618224  and accuracy 68%
# 48401 steps out of 100 steps : average 0.6735710795593151  and accuracy 77%
# 48501 steps out of 100 steps : average 0.5860176169983959  and accuracy 80%
# 48601 steps out of 100 steps : average 0.6548298425209207  and accuracy 77%
# 48701 steps out of 100 steps : average 0.8815559179511238  and accuracy 65%
# 48801 steps out of 100 steps : average 0.7868614142404988  and accuracy 77%
# 48901 steps out of 100 steps : average 0.7308409211179633  and accuracy 72%
# 49001 steps out of 100 steps : average 0.8983634438647524  and accuracy 61%
# 49101 steps out of 100 steps : average 0.8015237248772402  and accuracy 63%
# 49201 steps out of 100 steps : average 0.6448813073263316  and accuracy 79%
# 49301 steps out of 100 steps : average 0.5882242152034803  and accuracy 76%
# 49401 steps out of 100 steps : average 0.7503411753733039  and accuracy 73%
# 49501 steps out of 100 steps : average 0.7614341784017595  and accuracy 68%
# 49601 steps out of 100 steps : average 0.7428437531316829  and accuracy 74%
# 49701 steps out of 100 steps : average 0.8542735252741732  and accuracy 65%
# 49801 steps out of 100 steps : average 0.7381170203273313  and accuracy 79%
# 49901 steps out of 100 steps : average 0.7740248728300196  and accuracy 68%
# 50001 steps out of 100 steps : average 0.898019982292207  and accuracy 71%
# 50101 steps out of 100 steps : average 0.95608254182055  and accuracy 68%
# 50201 steps out of 100 steps : average 0.8254458491782158  and accuracy 70%
# 50301 steps out of 100 steps : average 0.8128965843292083  and accuracy 69%
# 50401 steps out of 100 steps : average 0.8601706594676816  and accuracy 67%
# 50501 steps out of 100 steps : average 0.6273967205302688  and accuracy 72%
# 50601 steps out of 100 steps : average 0.9105065549255725  and accuracy 65%
# 50701 steps out of 100 steps : average 0.7960235283283268  and accuracy 65%
# 50801 steps out of 100 steps : average 0.7152349110087977  and accuracy 72%
# 50901 steps out of 100 steps : average 0.744354703346621  and accuracy 71%
# 51001 steps out of 100 steps : average 0.7307820895413749  and accuracy 75%
# 51101 steps out of 100 steps : average 0.6741183901601709  and accuracy 77%
# 51201 steps out of 100 steps : average 0.8353778553622057  and accuracy 66%
# 51301 steps out of 100 steps : average 0.7919837091857228  and accuracy 75%
# 51401 steps out of 100 steps : average 0.7055596026070267  and accuracy 74%
# 51501 steps out of 100 steps : average 0.9174871946098528  and accuracy 63%
# 51601 steps out of 100 steps : average 0.7051275350403173  and accuracy 67%
# 51701 steps out of 100 steps : average 0.7469403510467794  and accuracy 72%
# 51801 steps out of 100 steps : average 0.8523233227239916  and accuracy 65%
# 51901 steps out of 100 steps : average 0.7419130174895255  and accuracy 67%
# 52001 steps out of 100 steps : average 0.6858348805840088  and accuracy 75%
# 52101 steps out of 100 steps : average 0.7641151620055292  and accuracy 73%
# 52201 steps out of 100 steps : average 0.6769740137989804  and accuracy 74%
# 52301 steps out of 100 steps : average 0.8249343401141701  and accuracy 71%
# 52401 steps out of 100 steps : average 0.9164732657444398  and accuracy 64%
# 52501 steps out of 100 steps : average 0.7064904595896973  and accuracy 72%
# 52601 steps out of 100 steps : average 0.8053951854728311  and accuracy 66%
# 52701 steps out of 100 steps : average 0.870856867615172  and accuracy 60%
# 52801 steps out of 100 steps : average 0.7933613632124117  and accuracy 73%
# 52901 steps out of 100 steps : average 0.7172948778506248  and accuracy 75%
# 53001 steps out of 100 steps : average 0.8233125521444543  and accuracy 74%
# 53101 steps out of 100 steps : average 0.7480918692283549  and accuracy 70%
# 53201 steps out of 100 steps : average 1.0064759846726752  and accuracy 59%
# 53301 steps out of 100 steps : average 0.8631329765987905  and accuracy 70%
# 53401 steps out of 100 steps : average 0.8233036047398856  and accuracy 74%
# 53501 steps out of 100 steps : average 0.7711595371182718  and accuracy 75%
# 53601 steps out of 100 steps : average 0.8280706348499552  and accuracy 64%
# 53701 steps out of 100 steps : average 0.7723787630562583  and accuracy 68%
# 53801 steps out of 100 steps : average 0.7035848100653417  and accuracy 75%
# 53901 steps out of 100 steps : average 0.7699585749254985  and accuracy 75%
# 54001 steps out of 100 steps : average 0.7805465383714204  and accuracy 69%
# 54101 steps out of 100 steps : average 0.7576315121559637  and accuracy 73%
# 54201 steps out of 100 steps : average 0.9893378773659908  and accuracy 57%
# 54301 steps out of 100 steps : average 0.9250101596118873  and accuracy 63%
# 54401 steps out of 100 steps : average 0.7277725315311627  and accuracy 71%
# 54501 steps out of 100 steps : average 0.8316504018576863  and accuracy 70%
# 54601 steps out of 100 steps : average 0.8385624058362035  and accuracy 70%
# 54701 steps out of 100 steps : average 0.7423926101411975  and accuracy 69%
# 54801 steps out of 100 steps : average 0.7694670789426555  and accuracy 70%
# 54901 steps out of 100 steps : average 0.8500817123377089  and accuracy 78%
# 55001 steps out of 100 steps : average 0.8065643041123604  and accuracy 68%
# 55101 steps out of 100 steps : average 0.8444332603652631  and accuracy 68%
# 55201 steps out of 100 steps : average 0.7568195272147399  and accuracy 78%
# 55301 steps out of 100 steps : average 0.6779094595730091  and accuracy 73%
# 55401 steps out of 100 steps : average 0.8131143173834015  and accuracy 70%
# 55501 steps out of 100 steps : average 0.809735087220336  and accuracy 70%
# 55601 steps out of 100 steps : average 0.8381126397814288  and accuracy 67%
# 55701 steps out of 100 steps : average 0.6962366796167041  and accuracy 73%
# 55801 steps out of 100 steps : average 0.729583318817916  and accuracy 76%
# 55901 steps out of 100 steps : average 0.6089067881998187  and accuracy 76%
# 56001 steps out of 100 steps : average 0.7799147426413022  and accuracy 74%
# 56101 steps out of 100 steps : average 0.9278039378681119  and accuracy 70%
# 56201 steps out of 100 steps : average 0.8344121969344128  and accuracy 70%
# 56301 steps out of 100 steps : average 0.612735679540645  and accuracy 79%
# 56401 steps out of 100 steps : average 0.7171981237069437  and accuracy 76%
# 56501 steps out of 100 steps : average 0.7306468344233373  and accuracy 73%
# 56601 steps out of 100 steps : average 0.8606913263808696  and accuracy 71%
# 56701 steps out of 100 steps : average 0.6747652352506421  and accuracy 77%
# 56801 steps out of 100 steps : average 0.6109281326159338  and accuracy 80%
# 56901 steps out of 100 steps : average 0.7479051500825488  and accuracy 72%
# 57001 steps out of 100 steps : average 0.8707541798739965  and accuracy 70%
# 57101 steps out of 100 steps : average 0.7960378969712623  and accuracy 73%
# 57201 steps out of 100 steps : average 0.8670386153953606  and accuracy 68%
# 57301 steps out of 100 steps : average 0.6735879649130119  and accuracy 74%
# 57401 steps out of 100 steps : average 0.682908084595443  and accuracy 73%
# 57501 steps out of 100 steps : average 0.7019896184709122  and accuracy 74%
# 57601 steps out of 100 steps : average 0.6987143799040841  and accuracy 72%
# 57701 steps out of 100 steps : average 0.7293432381612206  and accuracy 74%
# 57801 steps out of 100 steps : average 0.6670808415708919  and accuracy 77%
# 57901 steps out of 100 steps : average 0.7265872847621693  and accuracy 75%
# 58001 steps out of 100 steps : average 0.5733197158015436  and accuracy 79%
# 58101 steps out of 100 steps : average 0.7222964280897486  and accuracy 73%
# 58201 steps out of 100 steps : average 0.8946128003630842  and accuracy 63%
# 58301 steps out of 100 steps : average 0.6145363580332623  and accuracy 74%
# 58401 steps out of 100 steps : average 0.7554295157573414  and accuracy 73%
# 58501 steps out of 100 steps : average 0.7985326609740234  and accuracy 71%
# 58601 steps out of 100 steps : average 0.5127287202420904  and accuracy 81%
# 58701 steps out of 100 steps : average 0.786890017454445  and accuracy 68%
# 58801 steps out of 100 steps : average 0.8002133118048629  and accuracy 77%
# 58901 steps out of 100 steps : average 0.8217333999471087  and accuracy 71%
# 59001 steps out of 100 steps : average 0.7053438761774866  and accuracy 73%
# 59101 steps out of 100 steps : average 0.780740952449061  and accuracy 69%
# 59201 steps out of 100 steps : average 0.7673166695427757  and accuracy 73%
# 59301 steps out of 100 steps : average 0.7957215331404929  and accuracy 69%
# 59401 steps out of 100 steps : average 0.6537869495089967  and accuracy 76%
# 59501 steps out of 100 steps : average 0.7540705440961608  and accuracy 69%
# 59601 steps out of 100 steps : average 0.7046804256257257  and accuracy 72%
# 59701 steps out of 100 steps : average 0.78445951876418  and accuracy 71%
# 59801 steps out of 100 steps : average 0.7569259584573708  and accuracy 74%
# 59901 steps out of 100 steps : average 0.7384089332637224  and accuracy 67%
# Epoch => 3
# 101 steps out of 100 steps : average 0.5552963966670201  and accuracy 81%
# 201 steps out of 100 steps : average 0.7946430908392296  and accuracy 72%
# 301 steps out of 100 steps : average 0.898422823811217  and accuracy 69%
# 401 steps out of 100 steps : average 0.8505877430017995  and accuracy 71%
# 501 steps out of 100 steps : average 0.6202796635571355  and accuracy 79%
# 601 steps out of 100 steps : average 0.814791769291645  and accuracy 75%
# 701 steps out of 100 steps : average 0.8026880382366706  and accuracy 75%
# 801 steps out of 100 steps : average 0.6504933527622121  and accuracy 75%
# 901 steps out of 100 steps : average 0.7453478958120132  and accuracy 78%
# 1001 steps out of 100 steps : average 0.7437433786081347  and accuracy 72%
# 1101 steps out of 100 steps : average 0.7902127354996182  and accuracy 70%
# 1201 steps out of 100 steps : average 0.8625009733907327  and accuracy 69%
# 1301 steps out of 100 steps : average 0.7902452034162079  and accuracy 66%
# 1401 steps out of 100 steps : average 0.6991953506236149  and accuracy 73%
# 1501 steps out of 100 steps : average 0.7624187793852828  and accuracy 73%
# 1601 steps out of 100 steps : average 0.4662830623795955  and accuracy 82%
# 1701 steps out of 100 steps : average 0.7390106328795923  and accuracy 78%
# 1801 steps out of 100 steps : average 0.7745447039627896  and accuracy 72%
# 1901 steps out of 100 steps : average 0.8836111484441227  and accuracy 66%
# 2001 steps out of 100 steps : average 0.6793201340965309  and accuracy 75%
# 2101 steps out of 100 steps : average 0.679835788824812  and accuracy 72%
# 2201 steps out of 100 steps : average 0.7330229000421684  and accuracy 72%
# 2301 steps out of 100 steps : average 0.7387440049260167  and accuracy 70%
# 2401 steps out of 100 steps : average 0.6972816032234997  and accuracy 76%
# 2501 steps out of 100 steps : average 0.8712353266527291  and accuracy 64%
# 2601 steps out of 100 steps : average 0.7086952713591164  and accuracy 71%
# 2701 steps out of 100 steps : average 0.7347016451274644  and accuracy 74%
# 2801 steps out of 100 steps : average 0.740580581718217  and accuracy 69%
# 2901 steps out of 100 steps : average 0.7599976515910702  and accuracy 75%
# 3001 steps out of 100 steps : average 0.9520678273828896  and accuracy 63%
# 3101 steps out of 100 steps : average 0.8188839065561209  and accuracy 69%
# 3201 steps out of 100 steps : average 0.8063877354289343  and accuracy 72%
# 3301 steps out of 100 steps : average 0.8951880028049197  and accuracy 67%
# 3401 steps out of 100 steps : average 0.8058354934334464  and accuracy 69%
# 3501 steps out of 100 steps : average 0.6869290887223808  and accuracy 72%
# 3601 steps out of 100 steps : average 0.9637437970216618  and accuracy 68%
# 3701 steps out of 100 steps : average 0.803224037594084  and accuracy 67%
# 3801 steps out of 100 steps : average 0.6961959572518751  and accuracy 76%
# 3901 steps out of 100 steps : average 0.7890895785138966  and accuracy 79%
# 4001 steps out of 100 steps : average 0.894602666476948  and accuracy 67%
# 4101 steps out of 100 steps : average 0.8767536599899725  and accuracy 74%
# 4201 steps out of 100 steps : average 0.7476253799521366  and accuracy 75%
# 4301 steps out of 100 steps : average 0.8768734737296329  and accuracy 66%
# 4401 steps out of 100 steps : average 0.7643629995851847  and accuracy 72%
# 4501 steps out of 100 steps : average 0.7895618000392299  and accuracy 78%
# 4601 steps out of 100 steps : average 0.6179902851103778  and accuracy 78%
# 4701 steps out of 100 steps : average 0.5552512373751128  and accuracy 76%
# 4801 steps out of 100 steps : average 0.7516218042976145  and accuracy 75%
# 4901 steps out of 100 steps : average 0.6292470583284921  and accuracy 79%
# 5001 steps out of 100 steps : average 0.6748008827277308  and accuracy 75%
# 5101 steps out of 100 steps : average 0.9140724528425214  and accuracy 63%
# 5201 steps out of 100 steps : average 0.7603146499814882  and accuracy 66%
# 5301 steps out of 100 steps : average 0.7451795435952226  and accuracy 71%
# 5401 steps out of 100 steps : average 0.8158114079123249  and accuracy 68%
# 5501 steps out of 100 steps : average 0.7400389016788514  and accuracy 69%
# 5601 steps out of 100 steps : average 0.8326185116536816  and accuracy 75%
# 5701 steps out of 100 steps : average 0.7264636689222239  and accuracy 67%
# 5801 steps out of 100 steps : average 0.7065419781010027  and accuracy 72%
# 5901 steps out of 100 steps : average 0.5515121474860194  and accuracy 80%
# 6001 steps out of 100 steps : average 0.9168537141889168  and accuracy 71%
# 6101 steps out of 100 steps : average 0.6980195595344719  and accuracy 70%
# 6201 steps out of 100 steps : average 0.7735573969949272  and accuracy 71%
# 6301 steps out of 100 steps : average 0.8697731562978223  and accuracy 67%
# 6401 steps out of 100 steps : average 0.7495370765793047  and accuracy 73%
# 6501 steps out of 100 steps : average 0.9317290986046403  and accuracy 69%
# 6601 steps out of 100 steps : average 0.8617666087712607  and accuracy 73%
# 6701 steps out of 100 steps : average 0.7338289552797912  and accuracy 71%
# 6801 steps out of 100 steps : average 0.7238656047842289  and accuracy 75%
# 6901 steps out of 100 steps : average 0.7700772638328465  and accuracy 68%
# 7001 steps out of 100 steps : average 0.7261202474255123  and accuracy 73%
# 7101 steps out of 100 steps : average 0.7958793385845823  and accuracy 71%
# 7201 steps out of 100 steps : average 0.8097748976354754  and accuracy 70%
# 7301 steps out of 100 steps : average 0.7310836092093226  and accuracy 75%
# 7401 steps out of 100 steps : average 0.8415304541800055  and accuracy 64%
# 7501 steps out of 100 steps : average 0.8192973537935605  and accuracy 69%
# 7601 steps out of 100 steps : average 0.7665320654429882  and accuracy 72%
# 7701 steps out of 100 steps : average 1.0870754181149505  and accuracy 63%
# 7801 steps out of 100 steps : average 0.7724010214607501  and accuracy 70%
# 7901 steps out of 100 steps : average 0.732045459831177  and accuracy 71%
# 8001 steps out of 100 steps : average 0.8602584332916685  and accuracy 69%
# 8101 steps out of 100 steps : average 0.7952604304791727  and accuracy 70%
# 8201 steps out of 100 steps : average 0.738918264996586  and accuracy 68%
# 8301 steps out of 100 steps : average 0.7494435211391907  and accuracy 74%
# 8401 steps out of 100 steps : average 0.7850407256370296  and accuracy 68%
# 8501 steps out of 100 steps : average 0.6965068140771831  and accuracy 76%
# 8601 steps out of 100 steps : average 0.6500949607372943  and accuracy 76%
# 8701 steps out of 100 steps : average 0.7814765060375912  and accuracy 77%
# 8801 steps out of 100 steps : average 0.8291329015940184  and accuracy 67%
# 8901 steps out of 100 steps : average 0.7700605800160563  and accuracy 67%
# 9001 steps out of 100 steps : average 1.026385319408812  and accuracy 59%
# 9101 steps out of 100 steps : average 0.8159639277232589  and accuracy 66%
# 9201 steps out of 100 steps : average 0.8075889745076672  and accuracy 70%
# 9301 steps out of 100 steps : average 0.6190077484133091  and accuracy 80%
# 9401 steps out of 100 steps : average 0.7021290670273856  and accuracy 72%
# 9501 steps out of 100 steps : average 0.8512487495076725  and accuracy 66%
# 9601 steps out of 100 steps : average 0.7613938434294851  and accuracy 69%
# 9701 steps out of 100 steps : average 0.8652296048834036  and accuracy 68%
# 9801 steps out of 100 steps : average 0.7994337022923383  and accuracy 71%
# 9901 steps out of 100 steps : average 0.7381312049886585  and accuracy 71%
# 10001 steps out of 100 steps : average 0.8243655288858953  and accuracy 66%
# 10101 steps out of 100 steps : average 0.6755444870283135  and accuracy 70%
# 10201 steps out of 100 steps : average 0.7111291859344823  and accuracy 80%
# 10301 steps out of 100 steps : average 0.9529323257238783  and accuracy 67%
# 10401 steps out of 100 steps : average 0.6573479769480626  and accuracy 78%
# 10501 steps out of 100 steps : average 0.7832950356465227  and accuracy 70%
# 10601 steps out of 100 steps : average 0.6943842449473265  and accuracy 77%
# 10701 steps out of 100 steps : average 0.7303778980758214  and accuracy 67%
# 10801 steps out of 100 steps : average 0.7923773527696575  and accuracy 68%
# 10901 steps out of 100 steps : average 0.7378863596345829  and accuracy 71%
# 11001 steps out of 100 steps : average 0.7423623378561404  and accuracy 71%
# 11101 steps out of 100 steps : average 0.8266513043067404  and accuracy 68%
# 11201 steps out of 100 steps : average 0.6940415104213973  and accuracy 78%
# 11301 steps out of 100 steps : average 0.7022670519600192  and accuracy 74%
# 11401 steps out of 100 steps : average 0.731176802646744  and accuracy 72%
# 11501 steps out of 100 steps : average 0.8697506208556711  and accuracy 65%
# 11601 steps out of 100 steps : average 0.9003596987057986  and accuracy 70%
# 11701 steps out of 100 steps : average 0.7513544421659983  and accuracy 71%
# 11801 steps out of 100 steps : average 0.7789472765635033  and accuracy 69%
# 11901 steps out of 100 steps : average 0.8016428092776172  and accuracy 76%
# 12001 steps out of 100 steps : average 0.8167108967710729  and accuracy 63%
# 12101 steps out of 100 steps : average 0.7921390059771178  and accuracy 74%
# 12201 steps out of 100 steps : average 0.8637140973253843  and accuracy 64%
# 12301 steps out of 100 steps : average 0.79624239095911  and accuracy 67%
# 12401 steps out of 100 steps : average 0.6364532166608696  and accuracy 80%
# 12501 steps out of 100 steps : average 0.7129769266634924  and accuracy 74%
# 12601 steps out of 100 steps : average 0.6051048918209027  and accuracy 81%
# 12701 steps out of 100 steps : average 0.7107286891752865  and accuracy 78%
# 12801 steps out of 100 steps : average 0.850180294809049  and accuracy 72%
# 12901 steps out of 100 steps : average 0.5952770298929437  and accuracy 77%
# 13001 steps out of 100 steps : average 0.7063527832274472  and accuracy 73%
# 13101 steps out of 100 steps : average 0.6752489167959669  and accuracy 75%
# 13201 steps out of 100 steps : average 1.0072257538000848  and accuracy 65%
# 13301 steps out of 100 steps : average 0.6667987910323961  and accuracy 79%
# 13401 steps out of 100 steps : average 0.8141567242349556  and accuracy 71%
# 13501 steps out of 100 steps : average 0.8114017345765039  and accuracy 70%
# 13601 steps out of 100 steps : average 0.8354781924432914  and accuracy 66%
# 13701 steps out of 100 steps : average 0.7800699576558928  and accuracy 75%
# 13801 steps out of 100 steps : average 0.6414597563333904  and accuracy 77%
# 13901 steps out of 100 steps : average 0.6777113412649493  and accuracy 75%
# 14001 steps out of 100 steps : average 0.6910057495035674  and accuracy 76%
# 14101 steps out of 100 steps : average 0.876357575587158  and accuracy 66%
# 14201 steps out of 100 steps : average 0.818754178923582  and accuracy 67%
# 14301 steps out of 100 steps : average 0.6822941178597158  and accuracy 79%
# 14401 steps out of 100 steps : average 0.7099474298928174  and accuracy 74%
# 14501 steps out of 100 steps : average 0.8119883526129863  and accuracy 70%
# 14601 steps out of 100 steps : average 0.7948780615508526  and accuracy 72%
# 14701 steps out of 100 steps : average 0.8469387892752942  and accuracy 62%
# 14801 steps out of 100 steps : average 0.519053754301179  and accuracy 83%
# 14901 steps out of 100 steps : average 0.7068211863861892  and accuracy 71%
# 15001 steps out of 100 steps : average 0.779814647267104  and accuracy 68%
# 15101 steps out of 100 steps : average 0.734745985386981  and accuracy 73%
# 15201 steps out of 100 steps : average 0.8217345041143613  and accuracy 67%
# 15301 steps out of 100 steps : average 0.9583725964112617  and accuracy 65%
# 15401 steps out of 100 steps : average 0.7141145047563388  and accuracy 73%
# 15501 steps out of 100 steps : average 0.9224204311305708  and accuracy 66%
# 15601 steps out of 100 steps : average 0.7838193862025821  and accuracy 69%
# 15701 steps out of 100 steps : average 0.6960676578944275  and accuracy 74%
# 15801 steps out of 100 steps : average 0.8461039156611718  and accuracy 67%
# 15901 steps out of 100 steps : average 0.6324513127573831  and accuracy 79%
# 16001 steps out of 100 steps : average 0.7904041267265657  and accuracy 66%
# 16101 steps out of 100 steps : average 0.9108459527383362  and accuracy 66%
# 16201 steps out of 100 steps : average 0.7181140620757063  and accuracy 74%
# 16301 steps out of 100 steps : average 0.6656997331458734  and accuracy 75%
# 16401 steps out of 100 steps : average 0.7826393028028226  and accuracy 69%
# 16501 steps out of 100 steps : average 0.6597795018664467  and accuracy 75%
# 16601 steps out of 100 steps : average 0.8821550626083269  and accuracy 67%
# 16701 steps out of 100 steps : average 0.7947860010867052  and accuracy 67%
# 16801 steps out of 100 steps : average 1.0457889698035567  and accuracy 63%
# 16901 steps out of 100 steps : average 0.808310175323641  and accuracy 73%
# 17001 steps out of 100 steps : average 0.61864515846985  and accuracy 80%
# 17101 steps out of 100 steps : average 0.783085526581712  and accuracy 71%
# 17201 steps out of 100 steps : average 0.621304072502505  and accuracy 76%
# 17301 steps out of 100 steps : average 0.8907127546280391  and accuracy 68%
# 17401 steps out of 100 steps : average 0.9525223025826118  and accuracy 71%
# 17501 steps out of 100 steps : average 0.8732969393309905  and accuracy 68%
# 17601 steps out of 100 steps : average 0.8862393963897134  and accuracy 69%
# 17701 steps out of 100 steps : average 0.7385713329516109  and accuracy 71%
# 17801 steps out of 100 steps : average 0.6977204881717991  and accuracy 78%
# 17901 steps out of 100 steps : average 0.7635169436756267  and accuracy 75%
# 18001 steps out of 100 steps : average 0.774763104910727  and accuracy 72%
# 18101 steps out of 100 steps : average 1.077953575645415  and accuracy 64%
# 18201 steps out of 100 steps : average 0.7622882693295818  and accuracy 74%
# 18301 steps out of 100 steps : average 0.7415652827935447  and accuracy 69%
# 18401 steps out of 100 steps : average 0.5909931558248398  and accuracy 79%
# 18501 steps out of 100 steps : average 0.9080449134584301  and accuracy 61%
# 18601 steps out of 100 steps : average 0.8284980031243276  and accuracy 71%
# 18701 steps out of 100 steps : average 0.8383080449301833  and accuracy 62%
# 18801 steps out of 100 steps : average 0.5929437538827587  and accuracy 76%
# 18901 steps out of 100 steps : average 0.7283647839556808  and accuracy 68%
# 19001 steps out of 100 steps : average 0.8109856600504244  and accuracy 72%
# 19101 steps out of 100 steps : average 0.9053497539552187  and accuracy 61%
# 19201 steps out of 100 steps : average 0.6579201478267497  and accuracy 74%
# 19301 steps out of 100 steps : average 0.8371753464054896  and accuracy 67%
# 19401 steps out of 100 steps : average 0.8078501283015279  and accuracy 71%
# 19501 steps out of 100 steps : average 0.9098119092474648  and accuracy 71%
# 19601 steps out of 100 steps : average 0.6681010849575766  and accuracy 76%
# 19701 steps out of 100 steps : average 0.6621958712677127  and accuracy 77%
# 19801 steps out of 100 steps : average 0.619188504598431  and accuracy 77%
# 19901 steps out of 100 steps : average 1.0083895020430724  and accuracy 64%
# 20001 steps out of 100 steps : average 0.8604362579685845  and accuracy 70%
# 20101 steps out of 100 steps : average 0.8707646531585689  and accuracy 70%
# 20201 steps out of 100 steps : average 0.8006613781323363  and accuracy 67%
# 20301 steps out of 100 steps : average 0.7055301315442637  and accuracy 70%
# 20401 steps out of 100 steps : average 0.6606506334403899  and accuracy 79%
# 20501 steps out of 100 steps : average 0.7565003476637111  and accuracy 71%
# 20601 steps out of 100 steps : average 0.7546417802574682  and accuracy 72%
# 20701 steps out of 100 steps : average 0.8175200850290545  and accuracy 76%
# 20801 steps out of 100 steps : average 0.7004337759715699  and accuracy 73%
# 20901 steps out of 100 steps : average 0.6843382840401452  and accuracy 78%
# 21001 steps out of 100 steps : average 0.6510564923029051  and accuracy 76%
# 21101 steps out of 100 steps : average 0.7183142187836382  and accuracy 64%
# 21201 steps out of 100 steps : average 0.7110891379791044  and accuracy 80%
# 21301 steps out of 100 steps : average 0.6686299439613687  and accuracy 74%
# 21401 steps out of 100 steps : average 0.6911549519726877  and accuracy 75%
# 21501 steps out of 100 steps : average 0.8203711254418002  and accuracy 68%
# 21601 steps out of 100 steps : average 0.554096053856145  and accuracy 81%
# 21701 steps out of 100 steps : average 0.818178816830036  and accuracy 70%
# 21801 steps out of 100 steps : average 0.6766536376280942  and accuracy 71%
# 21901 steps out of 100 steps : average 0.9223718260223697  and accuracy 71%
# 22001 steps out of 100 steps : average 0.6852181564831632  and accuracy 73%
# 22101 steps out of 100 steps : average 0.7452564296765073  and accuracy 75%
# 22201 steps out of 100 steps : average 0.8069134015036412  and accuracy 69%
# 22301 steps out of 100 steps : average 0.7829881911634885  and accuracy 68%
# 22401 steps out of 100 steps : average 0.7474974840456994  and accuracy 77%
# 22501 steps out of 100 steps : average 0.5990931720201073  and accuracy 75%
# 22601 steps out of 100 steps : average 0.9188521376542705  and accuracy 73%
# 22701 steps out of 100 steps : average 0.6003462956017508  and accuracy 74%
# 22801 steps out of 100 steps : average 0.6354420520955044  and accuracy 73%
# 22901 steps out of 100 steps : average 0.7536816159829312  and accuracy 75%
# 23001 steps out of 100 steps : average 0.7737233718709224  and accuracy 72%
# 23101 steps out of 100 steps : average 0.8021293651790367  and accuracy 70%
# 23201 steps out of 100 steps : average 0.6712970100856934  and accuracy 72%
# 23301 steps out of 100 steps : average 0.6243761987860353  and accuracy 75%
# 23401 steps out of 100 steps : average 0.6145470972655062  and accuracy 75%
# 23501 steps out of 100 steps : average 0.7919375551516525  and accuracy 65%
# 23601 steps out of 100 steps : average 0.8425619105583931  and accuracy 69%
# 23701 steps out of 100 steps : average 0.8228552098269291  and accuracy 70%
# 23801 steps out of 100 steps : average 0.719226689504605  and accuracy 73%
# 23901 steps out of 100 steps : average 0.6879391113604889  and accuracy 80%
# 24001 steps out of 100 steps : average 0.7734583630887617  and accuracy 65%
# 24101 steps out of 100 steps : average 0.91768411839619  and accuracy 68%
# 24201 steps out of 100 steps : average 0.6844014743388221  and accuracy 78%
# 24301 steps out of 100 steps : average 0.6791916038079223  and accuracy 70%
# 24401 steps out of 100 steps : average 0.7060480569055578  and accuracy 72%
# 24501 steps out of 100 steps : average 0.7472410180464997  and accuracy 73%
# 24601 steps out of 100 steps : average 0.9560170329218414  and accuracy 64%
# 24701 steps out of 100 steps : average 0.673582810817762  and accuracy 76%
# 24801 steps out of 100 steps : average 0.7433768764434707  and accuracy 73%
# 24901 steps out of 100 steps : average 0.8033471197806066  and accuracy 72%
# 25001 steps out of 100 steps : average 0.6842443861284961  and accuracy 77%
# 25101 steps out of 100 steps : average 0.6119547991212461  and accuracy 78%
# 25201 steps out of 100 steps : average 0.6093847835488849  and accuracy 82%
# 25301 steps out of 100 steps : average 0.626324390938179  and accuracy 77%
# 25401 steps out of 100 steps : average 0.6977422637371705  and accuracy 77%
# 25501 steps out of 100 steps : average 0.7873290071705425  and accuracy 71%
# 25601 steps out of 100 steps : average 0.7798487677702383  and accuracy 71%
# 25701 steps out of 100 steps : average 0.7952907917193229  and accuracy 69%
# 25801 steps out of 100 steps : average 0.8130571613931736  and accuracy 65%
# 25901 steps out of 100 steps : average 0.6939774582230218  and accuracy 76%
# 26001 steps out of 100 steps : average 0.7679341384194399  and accuracy 72%
# 26101 steps out of 100 steps : average 0.6511890879819435  and accuracy 76%
# 26201 steps out of 100 steps : average 0.753793816577214  and accuracy 74%
# 26301 steps out of 100 steps : average 0.9022931214683768  and accuracy 65%
# 26401 steps out of 100 steps : average 0.768437112687427  and accuracy 70%
# 26501 steps out of 100 steps : average 0.7794060917805846  and accuracy 73%
# 26601 steps out of 100 steps : average 0.639833958343609  and accuracy 75%
# 26701 steps out of 100 steps : average 0.6721610964038993  and accuracy 78%
# 26801 steps out of 100 steps : average 0.7786826354992309  and accuracy 71%
# 26901 steps out of 100 steps : average 0.6857664431095593  and accuracy 77%
# 27001 steps out of 100 steps : average 0.7741731026702786  and accuracy 74%
# 27101 steps out of 100 steps : average 0.5651233382226207  and accuracy 78%
# 27201 steps out of 100 steps : average 0.8355692129454998  and accuracy 69%
# 27301 steps out of 100 steps : average 0.773988808213984  and accuracy 73%
# 27401 steps out of 100 steps : average 0.7547511040137854  and accuracy 73%
# 27501 steps out of 100 steps : average 0.9264238900305848  and accuracy 67%
# 27601 steps out of 100 steps : average 0.7953787483609942  and accuracy 69%
# 27701 steps out of 100 steps : average 0.7043987891860071  and accuracy 77%
# 27801 steps out of 100 steps : average 0.7074845118466664  and accuracy 74%
# 27901 steps out of 100 steps : average 0.6401653879795488  and accuracy 75%
# 28001 steps out of 100 steps : average 0.6786240325280146  and accuracy 74%
# 28101 steps out of 100 steps : average 0.8404517036364364  and accuracy 72%
# 28201 steps out of 100 steps : average 0.7100671088799002  and accuracy 68%
# 28301 steps out of 100 steps : average 0.760191982300162  and accuracy 75%
# 28401 steps out of 100 steps : average 0.6690608679007962  and accuracy 78%
# 28501 steps out of 100 steps : average 0.7108972109710681  and accuracy 76%
# 28601 steps out of 100 steps : average 0.8273735238120014  and accuracy 67%
# 28701 steps out of 100 steps : average 0.6321049386118969  and accuracy 71%
# 28801 steps out of 100 steps : average 0.7623859974803926  and accuracy 67%
# 28901 steps out of 100 steps : average 0.9057654308899626  and accuracy 71%
# 29001 steps out of 100 steps : average 0.7221760211059219  and accuracy 71%
# 29101 steps out of 100 steps : average 0.8552158519556028  and accuracy 69%
# 29201 steps out of 100 steps : average 0.7446788972106901  and accuracy 75%
# 29301 steps out of 100 steps : average 0.6510192213637034  and accuracy 74%
# 29401 steps out of 100 steps : average 0.7579503658225221  and accuracy 71%
# 29501 steps out of 100 steps : average 0.9897150040475424  and accuracy 68%
# 29601 steps out of 100 steps : average 0.7409695651752891  and accuracy 69%
# 29701 steps out of 100 steps : average 0.7811721575588038  and accuracy 71%
# 29801 steps out of 100 steps : average 0.9475177595012626  and accuracy 64%
# 29901 steps out of 100 steps : average 0.6967124927373011  and accuracy 71%
# 30001 steps out of 100 steps : average 0.6827876404168299  and accuracy 79%
# 30101 steps out of 100 steps : average 0.6927867888185066  and accuracy 71%
# 30201 steps out of 100 steps : average 0.789110545939701  and accuracy 76%
# 30301 steps out of 100 steps : average 0.8312146249384668  and accuracy 67%
# 30401 steps out of 100 steps : average 0.5653463006779708  and accuracy 75%
# 30501 steps out of 100 steps : average 0.6226835174229963  and accuracy 78%
# 30601 steps out of 100 steps : average 0.6571111030009046  and accuracy 78%
# 30701 steps out of 100 steps : average 0.8701860694200136  and accuracy 64%
# 30801 steps out of 100 steps : average 0.8016547676284511  and accuracy 71%
# 30901 steps out of 100 steps : average 0.8109270633391559  and accuracy 66%
# 31001 steps out of 100 steps : average 0.7044501128501716  and accuracy 72%
# 31101 steps out of 100 steps : average 0.6866602746877412  and accuracy 71%
# 31201 steps out of 100 steps : average 0.7006399452427938  and accuracy 71%
# 31301 steps out of 100 steps : average 0.6824265390888332  and accuracy 71%
# 31401 steps out of 100 steps : average 0.610925685375126  and accuracy 77%
# 31501 steps out of 100 steps : average 0.6800412313033708  and accuracy 71%
# 31601 steps out of 100 steps : average 0.6717038610146397  and accuracy 73%
# 31701 steps out of 100 steps : average 0.6682820933718565  and accuracy 77%
# 31801 steps out of 100 steps : average 0.7345612937507566  and accuracy 70%
# 31901 steps out of 100 steps : average 0.6277662565335469  and accuracy 79%
# 32001 steps out of 100 steps : average 0.589448359955602  and accuracy 77%
# 32101 steps out of 100 steps : average 0.7391113066838685  and accuracy 74%
# 32201 steps out of 100 steps : average 0.6144591978301233  and accuracy 78%
# 32301 steps out of 100 steps : average 0.8099113176283602  and accuracy 73%
# 32401 steps out of 100 steps : average 0.5881756905817069  and accuracy 78%
# 32501 steps out of 100 steps : average 0.8738958848570175  and accuracy 72%
# 32601 steps out of 100 steps : average 0.6109224998129186  and accuracy 76%
# 32701 steps out of 100 steps : average 0.6898953238228617  and accuracy 77%
# 32801 steps out of 100 steps : average 0.9549003507043722  and accuracy 58%
# 32901 steps out of 100 steps : average 0.6608566789546215  and accuracy 80%
# 33001 steps out of 100 steps : average 0.7386545195587426  and accuracy 75%
# 33101 steps out of 100 steps : average 0.6275701429397378  and accuracy 78%
# 33201 steps out of 100 steps : average 0.7506143191629103  and accuracy 76%
# 33301 steps out of 100 steps : average 0.7458042093119659  and accuracy 75%
# 33401 steps out of 100 steps : average 0.6763722363182768  and accuracy 75%
# 33501 steps out of 100 steps : average 0.8278585147956788  and accuracy 69%
# 33601 steps out of 100 steps : average 0.8781230085332611  and accuracy 63%
# 33701 steps out of 100 steps : average 0.7081837671238528  and accuracy 74%
# 33801 steps out of 100 steps : average 0.744948202730155  and accuracy 73%
# 33901 steps out of 100 steps : average 0.6984258128549744  and accuracy 74%
# 34001 steps out of 100 steps : average 0.9030693610680145  and accuracy 74%
# 34101 steps out of 100 steps : average 0.9329249135881373  and accuracy 64%
# 34201 steps out of 100 steps : average 0.602104246717075  and accuracy 76%
# 34301 steps out of 100 steps : average 0.7061842408803003  and accuracy 76%
# 34401 steps out of 100 steps : average 0.6950848140986294  and accuracy 71%
# 34501 steps out of 100 steps : average 0.6918822511484986  and accuracy 72%
# 34601 steps out of 100 steps : average 0.5152072689751851  and accuracy 80%
# 34701 steps out of 100 steps : average 0.6770646206578834  and accuracy 80%
# 34801 steps out of 100 steps : average 0.7495954507908159  and accuracy 79%
# 34901 steps out of 100 steps : average 0.7712334214080053  and accuracy 69%
# 35001 steps out of 100 steps : average 0.6984769710440628  and accuracy 80%
# 35101 steps out of 100 steps : average 0.5985795129282415  and accuracy 77%
# 35201 steps out of 100 steps : average 0.8695458661929888  and accuracy 73%
# 35301 steps out of 100 steps : average 0.6495569799882679  and accuracy 77%
# 35401 steps out of 100 steps : average 0.7737823734014236  and accuracy 77%
# 35501 steps out of 100 steps : average 0.6272610686345635  and accuracy 76%
# 35601 steps out of 100 steps : average 0.8748446000779728  and accuracy 70%
# 35701 steps out of 100 steps : average 0.7852965952431767  and accuracy 73%
# 35801 steps out of 100 steps : average 0.744909265630358  and accuracy 70%
# 35901 steps out of 100 steps : average 0.6092001963809578  and accuracy 78%
# 36001 steps out of 100 steps : average 0.6844273183204669  and accuracy 71%
# 36101 steps out of 100 steps : average 0.753428401300471  and accuracy 71%
# 36201 steps out of 100 steps : average 0.699108509315223  and accuracy 73%
# 36301 steps out of 100 steps : average 0.8259553054749271  and accuracy 67%
# 36401 steps out of 100 steps : average 1.0008722847602132  and accuracy 65%
# 36501 steps out of 100 steps : average 0.9591728471839809  and accuracy 67%
# 36601 steps out of 100 steps : average 0.6682632681298593  and accuracy 75%
# 36701 steps out of 100 steps : average 0.7040458275983991  and accuracy 77%
# 36801 steps out of 100 steps : average 0.9918352216674465  and accuracy 61%
# 36901 steps out of 100 steps : average 0.6320406619444972  and accuracy 73%
# 37001 steps out of 100 steps : average 0.6622058658889504  and accuracy 78%
# 37101 steps out of 100 steps : average 0.8355100752731985  and accuracy 65%
# 37201 steps out of 100 steps : average 0.6940820780281104  and accuracy 74%
# 37301 steps out of 100 steps : average 0.5994556004714163  and accuracy 78%
# 37401 steps out of 100 steps : average 0.660712809139946  and accuracy 72%
# 37501 steps out of 100 steps : average 0.812661629910712  and accuracy 69%
# 37601 steps out of 100 steps : average 0.6606117812883651  and accuracy 82%
# 37701 steps out of 100 steps : average 0.6564934050949759  and accuracy 78%
# 37801 steps out of 100 steps : average 0.5444804000554562  and accuracy 79%
# 37901 steps out of 100 steps : average 0.7396125274783492  and accuracy 70%
# 38001 steps out of 100 steps : average 0.8839377648177649  and accuracy 67%
# 38101 steps out of 100 steps : average 0.7939859468329058  and accuracy 73%
# 38201 steps out of 100 steps : average 0.8338282347211924  and accuracy 72%
# 38301 steps out of 100 steps : average 0.7392918468714462  and accuracy 75%
# 38401 steps out of 100 steps : average 0.6114531682092956  and accuracy 81%
# 38501 steps out of 100 steps : average 0.5734292194594225  and accuracy 83%
# 38601 steps out of 100 steps : average 0.7321042599929438  and accuracy 70%
# 38701 steps out of 100 steps : average 0.7373817175836272  and accuracy 71%
# 38801 steps out of 100 steps : average 0.6578563822859073  and accuracy 71%
# 38901 steps out of 100 steps : average 0.6649680540527371  and accuracy 78%
# 39001 steps out of 100 steps : average 0.729260089581299  and accuracy 71%
# 39101 steps out of 100 steps : average 0.7038753939149407  and accuracy 74%
# 39201 steps out of 100 steps : average 0.7222455844338559  and accuracy 75%
# 39301 steps out of 100 steps : average 0.8551347097050571  and accuracy 73%
# 39401 steps out of 100 steps : average 0.6087706126654673  and accuracy 82%
# 39501 steps out of 100 steps : average 0.719943158660122  and accuracy 78%
# 39601 steps out of 100 steps : average 0.6855659811040035  and accuracy 74%
# 39701 steps out of 100 steps : average 0.7390537448577316  and accuracy 74%
# 39801 steps out of 100 steps : average 0.7295981015154802  and accuracy 76%
# 39901 steps out of 100 steps : average 0.6911002157922153  and accuracy 73%
# 40001 steps out of 100 steps : average 0.6756123713013517  and accuracy 72%
# 40101 steps out of 100 steps : average 0.6826753422936167  and accuracy 70%
# 40201 steps out of 100 steps : average 0.8933171136514653  and accuracy 69%
# 40301 steps out of 100 steps : average 0.6999674475462632  and accuracy 69%
# 40401 steps out of 100 steps : average 0.6639375770964433  and accuracy 70%
# 40501 steps out of 100 steps : average 0.6419299410587569  and accuracy 77%
# 40601 steps out of 100 steps : average 0.8601796292984858  and accuracy 72%
# 40701 steps out of 100 steps : average 0.6487372106283735  and accuracy 74%
# 40801 steps out of 100 steps : average 0.7181318947665443  and accuracy 69%
# 40901 steps out of 100 steps : average 0.7591592626029648  and accuracy 72%
# 41001 steps out of 100 steps : average 0.6849654997906457  and accuracy 77%
# 41101 steps out of 100 steps : average 0.8342626731290765  and accuracy 74%
# 41201 steps out of 100 steps : average 0.6924251972866873  and accuracy 72%
# 41301 steps out of 100 steps : average 0.7340714845064098  and accuracy 69%
# 41401 steps out of 100 steps : average 0.7781974909298102  and accuracy 73%
# 41501 steps out of 100 steps : average 0.7506685335145744  and accuracy 68%
# 41601 steps out of 100 steps : average 0.6788583410500968  and accuracy 76%
# 41701 steps out of 100 steps : average 0.8074066192711902  and accuracy 69%
# 41801 steps out of 100 steps : average 0.6681366743577252  and accuracy 72%
# 41901 steps out of 100 steps : average 0.6885830518931259  and accuracy 77%
# 42001 steps out of 100 steps : average 0.7577442567456434  and accuracy 77%
# 42101 steps out of 100 steps : average 0.7615635290632757  and accuracy 69%
# 42201 steps out of 100 steps : average 0.7561346727115981  and accuracy 76%
# 42301 steps out of 100 steps : average 0.6929329347021012  and accuracy 74%
# 42401 steps out of 100 steps : average 0.7159332229026389  and accuracy 74%
# 42501 steps out of 100 steps : average 0.6300163671051073  and accuracy 74%
# 42601 steps out of 100 steps : average 0.7299803278699228  and accuracy 76%
# 42701 steps out of 100 steps : average 0.6643554789704449  and accuracy 77%
# 42801 steps out of 100 steps : average 0.6370458634573823  and accuracy 78%
# 42901 steps out of 100 steps : average 0.7387232134586823  and accuracy 72%
# 43001 steps out of 100 steps : average 0.6976308618425382  and accuracy 76%
# 43101 steps out of 100 steps : average 0.7459864379444515  and accuracy 69%
# 43201 steps out of 100 steps : average 0.8922012078569557  and accuracy 70%
# 43301 steps out of 100 steps : average 0.7998502443734173  and accuracy 72%
# 43401 steps out of 100 steps : average 0.9089979394523864  and accuracy 70%
# ...
# 39001 steps out of 100 steps : average 0.6390665432134693  and accuracy 78%
# 39101 steps out of 100 steps : average 0.6787410443944646  and accuracy 74%
# 39201 steps out of 100 steps : average 0.6539384834804431  and accuracy 74%
# 39301 steps out of 100 steps : average 0.7865177331507881  and accuracy 70%
# 39401 steps out of 100 steps : average 0.5383272591820282  and accuracy 79%
# 39501 steps out of 100 steps : average 0.6320466458832066  and accuracy 79%
# 39601 steps out of 100 steps : average 0.6595912848046558  and accuracy 75%
# 39701 steps out of 100 steps : average 0.6379601850840407  and accuracy 77%
# 39801 steps out of 100 steps : average 0.625997837543854  and accuracy 74%
# 39901 steps out of 100 steps : average 0.568454399181542  and accuracy 80%
# 40001 steps out of 100 steps : average 0.6644374023533611  and accuracy 70%
# 40101 steps out of 100 steps : average 0.5779867654360132  and accuracy 77%
# 40201 steps out of 100 steps : average 0.8445604990282556  and accuracy 66%
# 40301 steps out of 100 steps : average 0.6308119853912015  and accuracy 73%
# 40401 steps out of 100 steps : average 0.6104419982156766  and accuracy 73%
# 40501 steps out of 100 steps : average 0.589776698616614  and accuracy 78%
# 40601 steps out of 100 steps : average 0.7173645225829154  and accuracy 76%
# 40701 steps out of 100 steps : average 0.5978002493817343  and accuracy 76%
# 40801 steps out of 100 steps : average 0.6587392571257011  and accuracy 73%
# 40901 steps out of 100 steps : average 0.6859420036285083  and accuracy 73%
# 41001 steps out of 100 steps : average 0.5771560520635982  and accuracy 82%
# 41101 steps out of 100 steps : average 0.8579818686133912  and accuracy 75%
# 41201 steps out of 100 steps : average 0.7003307995207265  and accuracy 74%
# 41301 steps out of 100 steps : average 0.5788154364474153  and accuracy 76%
# 41401 steps out of 100 steps : average 0.749504547844487  and accuracy 71%
# 41501 steps out of 100 steps : average 0.7147261406643415  and accuracy 75%
# 41601 steps out of 100 steps : average 0.5955305758502291  and accuracy 78%
# 41701 steps out of 100 steps : average 0.7526961883563036  and accuracy 72%
# 41801 steps out of 100 steps : average 0.620658526023123  and accuracy 75%
# 41901 steps out of 100 steps : average 0.6569963497633605  and accuracy 75%
# 42001 steps out of 100 steps : average 0.7073361513498226  and accuracy 75%
# 42101 steps out of 100 steps : average 0.7351034567337414  and accuracy 68%
# 42201 steps out of 100 steps : average 0.697152457596407  and accuracy 77%
# 42301 steps out of 100 steps : average 0.6160975581326802  and accuracy 76%
# 42401 steps out of 100 steps : average 0.6927998101340702  and accuracy 75%
# 42501 steps out of 100 steps : average 0.5677346606733251  and accuracy 76%
# 42601 steps out of 100 steps : average 0.7486352989926534  and accuracy 74%
# 42701 steps out of 100 steps : average 0.5849320616020701  and accuracy 78%
# 42801 steps out of 100 steps : average 0.5369250635588118  and accuracy 80%
# 42901 steps out of 100 steps : average 0.5440315722592695  and accuracy 81%
# 43001 steps out of 100 steps : average 0.6874335879713466  and accuracy 78%
# 43101 steps out of 100 steps : average 0.6513765526537736  and accuracy 67%
# 43201 steps out of 100 steps : average 0.7604315632631077  and accuracy 76%
# 43301 steps out of 100 steps : average 0.6762919749807415  and accuracy 77%
# 43401 steps out of 100 steps : average 0.7906411771724672  and accuracy 75%
# 43501 steps out of 100 steps : average 0.7092644618199907  and accuracy 74%
# 43601 steps out of 100 steps : average 0.6525077590171854  and accuracy 75%
# 43701 steps out of 100 steps : average 0.4813975851270055  and accuracy 84%
# 43801 steps out of 100 steps : average 0.6276236075185967  and accuracy 76%
# 43901 steps out of 100 steps : average 0.7812451120418201  and accuracy 70%
# 44001 steps out of 100 steps : average 0.671334985946038  and accuracy 79%
# 44101 steps out of 100 steps : average 0.6193814461093062  and accuracy 72%
# 44201 steps out of 100 steps : average 0.7153730716669523  and accuracy 70%
# 44301 steps out of 100 steps : average 0.7282713739369611  and accuracy 75%
# 44401 steps out of 100 steps : average 0.675843595136786  and accuracy 75%
# 44501 steps out of 100 steps : average 0.6123792062479226  and accuracy 74%
# 44601 steps out of 100 steps : average 0.5832270572802656  and accuracy 79%
# 44701 steps out of 100 steps : average 0.6347407682280156  and accuracy 76%
# 44801 steps out of 100 steps : average 0.745022868257961  and accuracy 74%
# 44901 steps out of 100 steps : average 0.696417202509025  and accuracy 71%
# 45001 steps out of 100 steps : average 0.7987801206539892  and accuracy 67%
# 45101 steps out of 100 steps : average 0.6631651187656219  and accuracy 73%
# 45201 steps out of 100 steps : average 0.5767051874974706  and accuracy 79%
# 45301 steps out of 100 steps : average 0.7060936160606631  and accuracy 66%
# 45401 steps out of 100 steps : average 0.6686255138757237  and accuracy 78%
# 45501 steps out of 100 steps : average 0.584882390473105  and accuracy 77%
# 45601 steps out of 100 steps : average 0.6453896226179409  and accuracy 74%
# 45701 steps out of 100 steps : average 0.6708076178295194  and accuracy 74%
# 45801 steps out of 100 steps : average 0.6471776434677164  and accuracy 76%
# 45901 steps out of 100 steps : average 0.8253427126240659  and accuracy 72%
# 46001 steps out of 100 steps : average 0.6197986204213773  and accuracy 75%
# 46101 steps out of 100 steps : average 0.7088621553494933  and accuracy 74%
# 46201 steps out of 100 steps : average 0.6658619711109547  and accuracy 69%
# 46301 steps out of 100 steps : average 0.8174758278496115  and accuracy 62%
# 46401 steps out of 100 steps : average 0.6421766592440032  and accuracy 76%
# 46501 steps out of 100 steps : average 0.6583952420971763  and accuracy 74%
# 46601 steps out of 100 steps : average 0.5344127624806406  and accuracy 79%
# 46701 steps out of 100 steps : average 0.7081436200987886  and accuracy 73%
# 46801 steps out of 100 steps : average 0.7111008132010146  and accuracy 70%
# 46901 steps out of 100 steps : average 0.6670202230414097  and accuracy 77%
# 47001 steps out of 100 steps : average 0.7693435999104683  and accuracy 71%
# 47101 steps out of 100 steps : average 0.8134264785445255  and accuracy 74%
# 47201 steps out of 100 steps : average 0.8302336859045437  and accuracy 68%
# 47301 steps out of 100 steps : average 0.7535774298727677  and accuracy 74%
# 47401 steps out of 100 steps : average 0.7632121734976829  and accuracy 71%
# 47501 steps out of 100 steps : average 0.5857618986285413  and accuracy 76%
# 47601 steps out of 100 steps : average 0.8005678503299376  and accuracy 69%
# 47701 steps out of 100 steps : average 0.672099152270864  and accuracy 78%
# 47801 steps out of 100 steps : average 0.5848509555509591  and accuracy 77%
# 47901 steps out of 100 steps : average 0.6268075178110103  and accuracy 73%
# 48001 steps out of 100 steps : average 0.5550960033512752  and accuracy 80%
# 48101 steps out of 100 steps : average 0.5832715000748205  and accuracy 79%
# 48201 steps out of 100 steps : average 0.5304669688966798  and accuracy 76%
# 48301 steps out of 100 steps : average 0.692949617455536  and accuracy 74%
# 48401 steps out of 100 steps : average 0.5787710612689075  and accuracy 81%
# 48501 steps out of 100 steps : average 0.5547923226975159  and accuracy 80%
# 48601 steps out of 100 steps : average 0.5114204176119252  and accuracy 85%
# 48701 steps out of 100 steps : average 0.8057952244587989  and accuracy 66%
# 48801 steps out of 100 steps : average 0.7099761736966044  and accuracy 77%
# 48901 steps out of 100 steps : average 0.5741370535857817  and accuracy 79%
# 49001 steps out of 100 steps : average 0.7709050535920696  and accuracy 69%
# 49101 steps out of 100 steps : average 0.6953887169544801  and accuracy 73%
# 49201 steps out of 100 steps : average 0.523554360835346  and accuracy 86%
# 49301 steps out of 100 steps : average 0.46397090374734534  and accuracy 78%
# 49401 steps out of 100 steps : average 0.6084410756211711  and accuracy 75%
# 49501 steps out of 100 steps : average 0.6931440164790765  and accuracy 77%
# 49601 steps out of 100 steps : average 0.6638610884214442  and accuracy 84%
# 49701 steps out of 100 steps : average 0.7735488138694904  and accuracy 73%
# 49801 steps out of 100 steps : average 0.6561448336546754  and accuracy 83%
# 49901 steps out of 100 steps : average 0.6760142777123558  and accuracy 69%
# 50001 steps out of 100 steps : average 0.7778830973709873  and accuracy 75%
# 50101 steps out of 100 steps : average 0.8233595095841154  and accuracy 69%
# 50201 steps out of 100 steps : average 0.7530726967249687  and accuracy 71%
# 50301 steps out of 100 steps : average 0.6659812351486357  and accuracy 76%
# 50401 steps out of 100 steps : average 0.7734966921750503  and accuracy 68%
# 50501 steps out of 100 steps : average 0.4904930705580217  and accuracy 82%
# 50601 steps out of 100 steps : average 0.7973292415815142  and accuracy 67%
# 50701 steps out of 100 steps : average 0.63311251848556  and accuracy 73%
# 50801 steps out of 100 steps : average 0.687984661001743  and accuracy 71%
# 50901 steps out of 100 steps : average 0.6397244227000126  and accuracy 78%
# 51001 steps out of 100 steps : average 0.6226200209291457  and accuracy 79%
# 51101 steps out of 100 steps : average 0.5276502847533169  and accuracy 80%
# 51201 steps out of 100 steps : average 0.7027058770962203  and accuracy 72%
# 51301 steps out of 100 steps : average 0.7135382419909431  and accuracy 76%
# 51401 steps out of 100 steps : average 0.6005977767889391  and accuracy 75%
# 51501 steps out of 100 steps : average 0.8204513440052691  and accuracy 68%
# 51601 steps out of 100 steps : average 0.5968155346678037  and accuracy 79%
# 51701 steps out of 100 steps : average 0.8028854554212104  and accuracy 71%
# 51801 steps out of 100 steps : average 0.6904022300500813  and accuracy 78%
# 51901 steps out of 100 steps : average 0.629448311306899  and accuracy 76%
# 52001 steps out of 100 steps : average 0.5285130972673161  and accuracy 84%
# 52101 steps out of 100 steps : average 0.6711275915215468  and accuracy 77%
# 52201 steps out of 100 steps : average 0.5597730788507345  and accuracy 79%
# 52301 steps out of 100 steps : average 0.6945844300022546  and accuracy 73%
# 52401 steps out of 100 steps : average 0.7961818284249792  and accuracy 67%
# 52501 steps out of 100 steps : average 0.6601702215268759  and accuracy 73%
# 52601 steps out of 100 steps : average 0.6998361773964978  and accuracy 78%
# 52701 steps out of 100 steps : average 0.8013165462123426  and accuracy 70%
# 52801 steps out of 100 steps : average 0.7562574670167548  and accuracy 71%
# 52901 steps out of 100 steps : average 0.6252593790658827  and accuracy 78%
# 53001 steps out of 100 steps : average 0.659377114402901  and accuracy 74%
# 53101 steps out of 100 steps : average 0.6667592556986697  and accuracy 76%
# 53201 steps out of 100 steps : average 0.8606020846123008  and accuracy 67%
# 53301 steps out of 100 steps : average 0.7295467444487861  and accuracy 71%
# 53401 steps out of 100 steps : average 0.6877701666049698  and accuracy 73%
# 53501 steps out of 100 steps : average 0.7179403649610194  and accuracy 74%
# 53601 steps out of 100 steps : average 0.7098590754369724  and accuracy 75%
# 53701 steps out of 100 steps : average 0.747198574821522  and accuracy 73%
# 53801 steps out of 100 steps : average 0.6451399032772221  and accuracy 74%
# 53901 steps out of 100 steps : average 0.6879363902241414  and accuracy 74%
# 54001 steps out of 100 steps : average 0.6052917620982738  and accuracy 82%
# 54101 steps out of 100 steps : average 0.671742355220076  and accuracy 74%
# 54201 steps out of 100 steps : average 0.802261440162347  and accuracy 66%
# 54301 steps out of 100 steps : average 0.8041719377143829  and accuracy 71%
# 54401 steps out of 100 steps : average 0.5789947462111005  and accuracy 75%
# 54501 steps out of 100 steps : average 0.7006981277370994  and accuracy 74%
# 54601 steps out of 100 steps : average 0.7910358280916623  and accuracy 68%
# 54701 steps out of 100 steps : average 0.6620018856454635  and accuracy 69%
# 54801 steps out of 100 steps : average 0.5393999411732535  and accuracy 77%
# 54901 steps out of 100 steps : average 0.7747622761265248  and accuracy 76%
# 55001 steps out of 100 steps : average 0.7222234318737614  and accuracy 69%
# 55101 steps out of 100 steps : average 0.7882194164789594  and accuracy 67%
# 55201 steps out of 100 steps : average 0.5959380398996472  and accuracy 82%
# 55301 steps out of 100 steps : average 0.6149694619607409  and accuracy 80%
# 55401 steps out of 100 steps : average 0.7128433206634596  and accuracy 67%
# 55501 steps out of 100 steps : average 0.668053274685239  and accuracy 74%
# 55601 steps out of 100 steps : average 0.6986452864848275  and accuracy 74%
# 55701 steps out of 100 steps : average 0.5897845599722252  and accuracy 80%
# 55801 steps out of 100 steps : average 0.5982644162709283  and accuracy 78%
# 55901 steps out of 100 steps : average 0.5175782831294675  and accuracy 78%
# 56001 steps out of 100 steps : average 0.7461135554265076  and accuracy 74%
# 56101 steps out of 100 steps : average 0.7956794090369129  and accuracy 74%
# 56201 steps out of 100 steps : average 0.7425145763825945  and accuracy 66%
# 56301 steps out of 100 steps : average 0.5153652619538  and accuracy 76%
# 56401 steps out of 100 steps : average 0.588969546643977  and accuracy 81%
# 56501 steps out of 100 steps : average 0.6522949244573032  and accuracy 73%
# 56601 steps out of 100 steps : average 0.7155322771717674  and accuracy 73%
# 56701 steps out of 100 steps : average 0.5786709716339385  and accuracy 80%
# 56801 steps out of 100 steps : average 0.5191880363123509  and accuracy 81%
# 56901 steps out of 100 steps : average 0.681851284260054  and accuracy 75%
# 57001 steps out of 100 steps : average 0.701362694515257  and accuracy 76%
# 57101 steps out of 100 steps : average 0.7138168829809463  and accuracy 79%
# 57201 steps out of 100 steps : average 0.7521562348088247  and accuracy 70%
# 57301 steps out of 100 steps : average 0.5955516593156464  and accuracy 80%
# 57401 steps out of 100 steps : average 0.629535396993291  and accuracy 80%
# 57501 steps out of 100 steps : average 0.5749425541913439  and accuracy 77%
# 57601 steps out of 100 steps : average 0.557018088680073  and accuracy 84%
# 57701 steps out of 100 steps : average 0.6662372694214007  and accuracy 72%
# 57801 steps out of 100 steps : average 0.5629624591255517  and accuracy 80%
# 57901 steps out of 100 steps : average 0.5842535191356609  and accuracy 79%
# 58001 steps out of 100 steps : average 0.5144677373291446  and accuracy 78%
# 58101 steps out of 100 steps : average 0.6920243362115877  and accuracy 73%
# 58201 steps out of 100 steps : average 0.7703861585183006  and accuracy 70%
# 58301 steps out of 100 steps : average 0.47451685426687407  and accuracy 80%
# 58401 steps out of 100 steps : average 0.6487265084636838  and accuracy 74%
# 58501 steps out of 100 steps : average 0.7014421595803637  and accuracy 73%
# 58601 steps out of 100 steps : average 0.4300082458765045  and accuracy 84%
# 58701 steps out of 100 steps : average 0.7406847181442773  and accuracy 70%
# 58801 steps out of 100 steps : average 0.7100795953806144  and accuracy 75%
# 58901 steps out of 100 steps : average 0.6500309799382875  and accuracy 77%
# 59001 steps out of 100 steps : average 0.635948487135898  and accuracy 74%
# 59101 steps out of 100 steps : average 0.6015174677143112  and accuracy 82%
# 59201 steps out of 100 steps : average 0.6307168857577484  and accuracy 81%
# 59301 steps out of 100 steps : average 0.6260085799224793  and accuracy 77%
# 59401 steps out of 100 steps : average 0.5360017375847456  and accuracy 82%
# 59501 steps out of 100 steps : average 0.6716347996294421  and accuracy 77%
# 59601 steps out of 100 steps : average 0.5995967670389126  and accuracy 77%
# 59701 steps out of 100 steps : average 0.6413700067708596  and accuracy 75%
# 59801 steps out of 100 steps : average 0.6466910682508622  and accuracy 76%
# 59901 steps out of 100 steps : average 0.647954952733165  and accuracy 76%

# %%
loss = 0
num_correct = 0
for im,label in zip(x_test,y_test):
  _,l1,acc = forward(im,label)
  loss += l1
  num_correct += acc
num_test = len(x_test)
print("Test loss :",loss/num_test)
print("Test accuracy :",num_correct/num_test)
# Out:
# Test loss : 0.6809783803332431
# Test accuracy : 0.7483
