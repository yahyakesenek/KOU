# %% [markdown]
# <a href="https://colab.research.google.com/github/yahyakesenek/KOU/blob/master/odev4_varyason_beklenede%C4%9Fer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import *
x=Symbol("x")
sum=0
n=4
for i in range(1,n+1):
  sum +=i
c=1/sum
def f(x):
  return c*x

print("c) C DEĞERİ ")
print("c = 1/Σf(x) => c = {}\n\n".format(c))

print("d) E(X) DEĞERİ")
print("E(x) = Σxf(x) => ")
sum = 0
str_=""
for i in range(1,n+1):
  print("{}*{} => {}".format(i,round(f(i),4),round(i*f(i),4)))
  sum +=round(i*f(i),4)
  if i==1:
    str_="{}*{}".format(i,round(f(i),4))
  else:
     str_ +="+{}*{}".format(i,round(f(i),4))
    
print("\n\n{} => E(x) = {}\n".format(str_,sum))
ex=sum**2
sum = 0

print("e) Var(x) DEĞERİ")
str_=""
for i in range(1,n+1):
  print("{}^2*{} => {}".format(i,round(f(i),4),round(i**2*f(i),4)))
  sum +=round(i**2*f(i),4)
  if i==1:
    str_="{}*{}".format(i,round(f(i),4))
  else:
     str_ +="+{}*{}".format(i,round(f(i),4))

print("\n var(x) = E(x^2)-[E(x)]^2 => {}-{} => {}".format(sum,ex,sum-ex))

print("e) P(x=1)) DEĞERİ")
print("\n P(x=1) => {} ".format(f(1)))

print("e) P(2<x<=4)  DEĞERİ")
print("\n P(2<x<=4) => Σf(x) = f(3)+f(4) =>  {} + {} => {} ".format(round(f(3),4),round(f(4),4),round(f(3)+f(4),4)))

print("e) P(x<=3) DEĞERİ")

print("\n P(x<=3) => 1-f(4)  => 1- {} => {} ".format(round(f(4),4),round(1-f(4),4)))
# Out:
# c) C DEĞERİ
# c = 1/Σf(x) => c = 0.1
#
#
# d) E(X) DEĞERİ
# E(x) = Σxf(x) =>
# 1*0.1 => 0.1
# 2*0.2 => 0.4
# 3*0.3 => 0.9
# 4*0.4 => 1.6
#
#
# 1*0.1+2*0.2+3*0.3+4*0.4 => E(x) = 3.0
#
# e) Var(x) DEĞERİ
# 1^2*0.1 => 0.1
# 2^2*0.2 => 0.8
# 3^2*0.3 => 2.7
# 4^2*0.4 => 6.4
#
#  var(x) = E(x^2)-[E(x)]^2 => 10.0-9.0 => 1.0
# e) P(x=1)) DEĞERİ
#
#  P(x=1) => 0.1
# e) P(2<x<=4)  DEĞERİ
#
#  P(2<x<=4) => Σf(x) = f(3)+f(4) =>  0.3 + 0.4 => 0.7
# e) P(x<=3) DEĞERİ
#
#  P(x<=3) => 1-f(4)  => 1- 0.4 => 0.6
